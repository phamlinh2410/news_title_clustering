# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import sys,time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import scipy.spatial.distance as distance
from sklearn import metrics

# %%
def dist(vecA, vecB):
    return np.sqrt(np.power(vecA - vecB, 2).sum())

# %%
class CureCluster:
    def __init__(self, id__, center__):
        self.points = center__
        self.repPoints = center__
        self.center = center__
        self.index = [id__]
        
    def __repr__(self):
        return "Cluster " + " Size: " + str(len(self.points))
    
    # Computes and stores the centroid of this cluster, based on its points
    def computeCentroid(self, clust):
        totalPoints_1 = len(self.index)
        totalPoints_2 = len(clust.index)
        self.center = (self.center*totalPoints_1 + clust.center*totalPoints_2) / (totalPoints_1 + totalPoints_2)
    
    # Computes and stores representative points for this cluster
    def generateRepPoints(self, numRepPoints, alpha):
        tempSet = None
        for i in range(1, numRepPoints+1):
            maxDist = 0
            maxPoint = None
            for p in range(0, len(self.index)):
                if i == 1:
                    minDist = dist(self.points[p,:], self.center)
                else:
                    X = np.vstack([tempSet, self.points[p, :]])
                    tmpDist = distance.pdist(X)
                    minDist = tmpDist.min()
                if minDist >= maxDist:
                    maxDist = minDist
                    maxPoint = self.points[p,:]
            if tempSet is None:
                tempSet = maxPoint
            else:
                tempSet = np.vstack((tempSet, maxPoint))
        for j in range(len(tempSet)):
            if self.repPoints is None:
                self.repPoints = tempSet[j,:] + alpha * (self.center - tempSet[j,:])
            else:
                self.repPoints = np.vstack((self.repPoints, tempSet[j,:] + alpha * (self.center - tempSet[j,:])))

    # Computes and stores distance between this cluster and the other one.
    def distRep(self, clust):
        distRep = float('inf')
        for repA in self.repPoints:
            if type(clust.repPoints[0]) != list:
                repB = clust.repPoints
                distTemp = dist(repA, repB)
                if distTemp < distRep:
                    distRep = distTemp
            else:
                for repB in clust.repPoints:
                    distTemp = dist(repA, repB)
                    if distTemp < distRep:
                        distRep = distTemp
        return distRep

    # Merges this cluster with the given cluster, recomputing the centroid and the representative points.
    def mergeWithCluster(self, clust, numRepPoints, alpha):
        self.computeCentroid(clust)
        self.points = np.vstack((self.points, clust.points))
        self.index = np.append(self.index, clust.index)
        self.repPoints = None
        self.generateRepPoints(numRepPoints, alpha)

# %%
def runCURE(data, numRepPoints, alpha, numDesCluster):

    # Initialization for clusters
    Clusters = []
    numCluster = len(data)
    numPts = len(data)
    distCluster = np.ones([len(data), len(data)])
    distCluster = distCluster * float('inf')
    for idPoint in range(len(data)):
        newClust = CureCluster(idPoint, data[idPoint,:])
        Clusters.append(newClust)
    for row in range(0, numPts):
        for col in range(0, row):
            distCluster[row][col] = dist(Clusters[row].center, Clusters[col].center)
    while numCluster > numDesCluster:
        if np.mod(numCluster, 50) == 0:
            print('Cluster count:', numCluster)

        # Find a pair of closet clusters
        minIndex = np.where(distCluster == np.min(distCluster))
        minIndex1 = minIndex[0][0]
        minIndex2 = minIndex[1][0]

        # Merge
        Clusters[minIndex1].mergeWithCluster(Clusters[minIndex2], numRepPoints, alpha)
        # Update the distCluster matrix
        for i in range(0, minIndex1):
            distCluster[minIndex1, i] = Clusters[minIndex1].distRep(Clusters[i])
        for i in range(minIndex1+1, numCluster):
            distCluster[i, minIndex1] = Clusters[minIndex1].distRep(Clusters[i])
        # Delete the merged cluster and its disCluster vector.
        distCluster = np.delete(distCluster, minIndex2, axis=0)
        distCluster = np.delete(distCluster, minIndex2, axis=1)
        del Clusters[minIndex2]
        numCluster = numCluster - 1

    print('Cluster count:', numCluster)
    # Generate sample labels
    Label = [0] * numPts
    for i in range(0, len(Clusters)):
        for j in range(0, len(Clusters[i].index)):
            Label[Clusters[i].index[j]] = i + 1

    return Label

# %%
sentences = []
vectors = []
with open("/content/drive/MyDrive/Colab_Notebooks/Mining of massive datasets/FinalExam/fasttext_vec100.json", encoding="utf-8") as file:
    data = json.load(file)
    # print(data[0])
    
    count = 1
    for k , v in data.items():
        if count > 10000 :
            break
        # print(k)
        sentences.append(k)
        vectors.append(v)
        count += 1

# %%
data = pd.DataFrame(vectors)
scaler = StandardScaler()
data_std = scaler.fit_transform(data)
pca = PCA(n_components = 2)
data_pca = pca.fit_transform(data_std)

# %%
# The number of representative points
numRepPoints = 4
# Shrink factor
alpha = 0.1
# Desired cluster number
numDesCluster = 15

start = time.process_time()

# data_set = np.loadtxt('/content/drive/MyDrive/Colab_Notebooks/Mining of massive datasets/Teach_n_Train/data_mining/thuchanh/data/data2_10_15clust.txt')

print("Please wait for CURE clustering to accomplete...")
Label_pre = runCURE(data_pca, numRepPoints, alpha, numDesCluster)
print("The CURE clustering is accompleted!!\n")

#end = time.clock()

print("The time of CURE algorithm is", time.process_time(), "\n")
# # Compute the NMI
# # nmi = metrics.v_measure_score(Label_true, Label_pre)
# # print("NMI =", nmi)
# # Plot the result
# plt.subplot(121)
# plt.scatter(data_pca[:, 0], data_pca[:, 1], marker='.')
# plt.text(0, 0, "origin")
# # plt.subplot(122)
# # scatterColors = ['black', 'blue', 'green', 'yellow', 'red', 'purple', 'orange', 'brown', 'cyan', 'brown',
# #                  'chocolate', 'darkgreen', 'darkblue', 'azure', 'bisque', 'pink']
# # for i in range(data_pca.shape[0]):
# #     color = scatterColors[Label_pre[i]]
# #     plt.scatter(data_pca[i, 0], data_pca[i, 1], marker='.', c=color)
# # plt.text(0, 0, "clusterResult")
# # plt.show()
# Out:
# Please wait for CURE clustering to accomplete...
# Cluster count: 10000
# Cluster count: 9950
# Cluster count: 9900
# Cluster count: 9850
# Cluster count: 9800
# Cluster count: 9750
# Cluster count: 9700
# Cluster count: 9650
# Cluster count: 9600
# Cluster count: 9550
# Cluster count: 9500
# Cluster count: 9450
# Cluster count: 9400
# Cluster count: 9350
# Cluster count: 9300
# Cluster count: 9250
# Cluster count: 9200
# Cluster count: 9150
# Cluster count: 9100
# Cluster count: 9050
# Cluster count: 9000
# Cluster count: 8950
# Cluster count: 8900
# Cluster count: 8850
# Cluster count: 8800
# Cluster count: 8750
# Cluster count: 8700
# Cluster count: 8650
# Cluster count: 8600
# Cluster count: 8550
# Cluster count: 8500
# Cluster count: 8450
# Cluster count: 8400
# Cluster count: 8350
# Cluster count: 8300
# Cluster count: 8250
# Cluster count: 8200
# Cluster count: 8150
# Cluster count: 8100
# Cluster count: 8050
# Cluster count: 8000
# Cluster count: 7950
# Cluster count: 7900
# Cluster count: 7850
# Cluster count: 7800
# Cluster count: 7750
# Cluster count: 7700
# Cluster count: 7650
# Cluster count: 7600
# Cluster count: 7550
# Cluster count: 7500
# Cluster count: 7450
# Cluster count: 7400
# Cluster count: 7350
# Cluster count: 7300
# Cluster count: 7250
# Cluster count: 7200
# Cluster count: 7150
# Cluster count: 7100
# Cluster count: 7050
# Cluster count: 7000
# Cluster count: 6950
# Cluster count: 6900
# Cluster count: 6850
# Cluster count: 6800
# Cluster count: 6750
# Cluster count: 6700
# Cluster count: 6650
# Cluster count: 6600
# Cluster count: 6550
# Cluster count: 6500
# Cluster count: 6450
# Cluster count: 6400
# Cluster count: 6350
# Cluster count: 6300
# Cluster count: 6250
# Cluster count: 6200
# Cluster count: 6150
# Cluster count: 6100
# Cluster count: 6050
# Cluster count: 6000
# Cluster count: 5950
# Cluster count: 5900
# Cluster count: 5850
# Cluster count: 5800
# Cluster count: 5750
# Cluster count: 5700
# Cluster count: 5650
# Cluster count: 5600
# Cluster count: 5550
# Cluster count: 5500
# Cluster count: 5450
# Cluster count: 5400
# Cluster count: 5350
# Cluster count: 5300
# Cluster count: 5250
# Cluster count: 5200
# Cluster count: 5150
# Cluster count: 5100
# Cluster count: 5050
# Cluster count: 5000
# Cluster count: 4950
# Cluster count: 4900
# Cluster count: 4850
# Cluster count: 4800
# Cluster count: 4750
# Cluster count: 4700
# Cluster count: 4650
# Cluster count: 4600
# Cluster count: 4550
# Cluster count: 4500
# Cluster count: 4450
# Cluster count: 4400
# Cluster count: 4350
# Cluster count: 4300
# Cluster count: 4250
# Cluster count: 4200
# Cluster count: 4150
# Cluster count: 4100
# Cluster count: 4050
# Cluster count: 4000
# Cluster count: 3950
# Cluster count: 3900
# Cluster count: 3850
# Cluster count: 3800
# Cluster count: 3750
# Cluster count: 3700
# Cluster count: 3650
# Cluster count: 3600
# Cluster count: 3550
# Cluster count: 3500
# Cluster count: 3450
# Cluster count: 3400
# Cluster count: 3350
# Cluster count: 3300
# Cluster count: 3250
# Cluster count: 3200
# Cluster count: 3150
# Cluster count: 3100
# Cluster count: 3050
# Cluster count: 3000
# Cluster count: 2950
# Cluster count: 2900
# Cluster count: 2850
# Cluster count: 2800
# Cluster count: 2750
# Cluster count: 2700
# Cluster count: 2650
# Cluster count: 2600
# Cluster count: 2550
# Cluster count: 2500
# Cluster count: 2450
# Cluster count: 2400
# Cluster count: 2350
# Cluster count: 2300
# Cluster count: 2250
# Cluster count: 2200
# Cluster count: 2150
# Cluster count: 2100
# Cluster count: 2050
# Cluster count: 2000
# Cluster count: 1950
# Cluster count: 1900
# Cluster count: 1850
# Cluster count: 1800
# Cluster count: 1750
# Cluster count: 1700
# Cluster count: 1650
# Cluster count: 1600
# Cluster count: 1550
# Cluster count: 1500
# Cluster count: 1450
# Cluster count: 1400
# Cluster count: 1350
# Cluster count: 1300
# Cluster count: 1250
# Cluster count: 1200
# Cluster count: 1150
# Cluster count: 1100
# Cluster count: 1050
# Cluster count: 1000
# Cluster count: 950
# Cluster count: 900
# Cluster count: 850
# Cluster count: 800
# Cluster count: 750
# Cluster count: 700
# Cluster count: 650
# Cluster count: 600
# Cluster count: 550
# Cluster count: 500
# Cluster count: 450
# Cluster count: 400
# Cluster count: 350
# Cluster count: 300
# Cluster count: 250
# Cluster count: 200
# Cluster count: 150
# Cluster count: 100
# Cluster count: 50
# Cluster count: 15
# The CURE clustering is accompleted!!
#
# The time of CURE algorithm is 5526.943302139

# %%
# Plot the result
plt.subplot(121)
plt.scatter(data_pca[:, 0], data_pca[:, 1], marker='.')
plt.text(0, 0, "origin")
plt.subplot(122)
scatterColors = ['black', 'blue', 'green', 'yellow', 'red', 'purple', 'orange', 'brown', 'cyan', 'brown',
                 'chocolate', 'darkgreen', 'darkblue', 'azure', 'bisque', 'pink']
for i in range(data_pca.shape[0]):
    color = scatterColors[Label_pre[i]]
    plt.scatter(data_pca[i, 0], data_pca[i, 1], marker='.', c=color)
plt.text(0, 0, "clusterResult")
plt.show()

# %%
print(Label_pre[0:10])
# Out:
# [10, 14, 12, 7, 11, 8, 7, 14, 14, 11]

# %%
print(sentences[0:10])
# Out:
# ['Chây ì nộp phạt nguội.', 'Cháu đòi tiền cơm, dì đòi tiền nhà.', 'Đà Nẵng nghiên cứu tiện ích nhắn tin khi vi phạm đến chủ phương tiện.', 'Khó xử vụ mẹ 70 tuổi trộm xe hơi của con gái.', 'Thay đổi về đăng ký, chuyển nhượng xe từ 12/2 bạn cần biết.', 'Những trường hợp cần trưng cầu giám định trong vụ án kinh tế.', 'Thị trấn Ollolai ở Italia bán nhà với giá hơn 1 USD để thu hút cư dân.', 'Bỏ quy định bán, tặng xe ô tô phải thông báo với công an.', 'Từ 12/2/2018: Người bán, tặng xe ô tô không phải thông báo với công an.', "Cái kết đắng chát sau 20 năm đám cưới là lời tuyên bố của chồng tệ bạc: 'Giải tán đi, tôi lấy vợ khác'."]

# %%
result = {}
for i in range(0, len(sentences)):
    result[sentences[i]] = Label_pre[i]

with open("/content/drive/MyDrive/Colab_Notebooks/Mining of massive datasets/FinalExam/Label_pre_CURE_10000.json", "w", encoding="utf-8") as file_out:
    json.dump(result, file_out, ensure_ascii=False)
